# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

data = []
for i in range(1, 5):
    url = f"https://startcoding.pythonanywhere.com/basic?page={i}"
    response = requests.get(url)
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    
    items = soup.select(".product")
    
    for item in items:
        img = item.select_one('.product-img > img').attrs['src']
        category = item.select_one('.product-category').text
        name = item.select_one('.product-name > a').text
        link = item.select_one('.product-name > a').attrs['href']
        # price = item.select_one('.product-price').text.strip().replace(',', '').replace('원', '')
        price = item.select_one('.product-price').text.strip().split('원')[0].replace(',', '')
        
        # print(img, category, name, link, price)
        
        data.append([img, category, name, link, price])

data
# Out:
# [['../static/img/product01.png',
#   '노트북',
#   '에이서 스위프트 GO 16 OLED, 스틸 그레이, 코어i7, 512GB, 16GB, WIN11 Home, SFG16-71-77FT',
#   '#product1_detail.html',
#   '1419000'],
#  ['../static/img/product02.png',
#   '노트북',
#   '삼성전자 노트북 플러스2 15.6, 퓨어 화이트, NT550XDA-K24AT, 펜티엄, 256GB, 8GB, WIN11 Pro',
#   '#product2_detail.html',
#   '549000'],
#  ['../static/img/product03.png',
#   '노트북',
#   '레노버 아이디어패드 슬림 1 15AMN7 15.6, 256GB, Free DOS, 82VG002EKR, 라이젠3, Cloud Grey (82VG), 8GB',
#   '#product3_detail.html',
#   '529000'],
#  ['../static/img/product04.png',
#   '노트북',
#   '레노버 V15 G4 AMN 15.6, Arctic Grey, 라이젠3, 256GB, 8GB, WIN11 Home, 82YU0009KR',
#   '#product4_detail.html',
#   '624000'],
#  ['../static/img/product05.png',
#   '노트북',
#   'LG 울트라PC 엣지 16, 차콜 그레이, 라이젠5, 256GB, 16GB, WIN11 Home, 16U70R-GA56K',
#   '#product5_detail.html',
#   '1135000'],
#  ['../static/img/product06.png',
#   '노트북',
#   '베이직스 베이직북 14 3세대, BB1422SS, 256GB, White, WIN11 Pro, 셀러론, 8GB',
# ...

# %%
# 데이터 프레임 만들기
df = pd.DataFrame(data, columns=['이미지', '카테고리', '상품명', '링크', '가격'])
df
# Out:
#                             이미지  카테고리  \
# 0   ../static/img/product01.png   노트북
# 1   ../static/img/product02.png   노트북
# 2   ../static/img/product03.png   노트북
# 3   ../static/img/product04.png   노트북
# 4   ../static/img/product05.png   노트북
# 5   ../static/img/product06.png   노트북
# 6   ../static/img/product07.png   노트북
# 7   ../static/img/product08.png   노트북
# 8   ../static/img/product09.png   노트북
# 9   ../static/img/product10.png   노트북
# 10  ../static/img/product11.png  데스크탑
# 11  ../static/img/product12.png  데스크탑
# 12  ../static/img/product13.png  데스크탑
# 13  ../static/img/product14.png  데스크탑
# 14  ../static/img/product15.png  데스크탑
# 15  ../static/img/product16.png  데스크탑
# 16  ../static/img/product17.png  데스크탑
# 17  ../static/img/product18.png  데스크탑
# 18  ../static/img/product19.png  데스크탑
# 19  ../static/img/product20.png  데스크탑
# 20  ../static/img/product21.png   휴대폰
# 21  ../static/img/product22.png   휴대폰
# 22  ../static/img/product23.png   휴대폰
# ...

# %%
# 엑셀 저장
df.to_excel('result.xlsx', index=False)
